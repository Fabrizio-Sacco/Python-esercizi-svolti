# %% [markdown]
# Creare un programma che chieda all'utente di inserire il proprio nome e la propria età. Stampa un messaggio indirizzato a loro che dichi l'anno in cui compiranno 100 anni.

# %%
A = input("Inserisci il tuo nome: ")
B = input("Inserisci la tua età: ")

C = 100 - int(B) 
D = int(C) + 2021

print(f"Ciao {A}!")
print(f"Nel {D} compirai 100 anni!")
# Out:
# Inserisci il tuo nome: Batman
# Inserisci la tua età: 45
# Ciao Batman!
# Nel 2076 compirai 100 anni!
